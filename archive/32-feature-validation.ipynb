# %% [markdown]
# # 32-feature-engineering-validation

# %%
# importing needed packages
import pandas as pd

# %%
# saving the biggest data set from 2015 to Oct 2018 to review features that we created
validation_data = pd.read_csv('fe_data/2015_18_10.csv')

# %%
# take a look at the data
validation_data
# Out:
#           indiv_id  total_transaction  sales_total  tire_purchases  \
# 0      251635131.0                  8       487.75               1
# 1      251636073.0                 19      2656.93               4
# 2      251636235.0                  1         0.00               0
# 3      251636752.0                 11      1678.38               1
# 4      251638270.0                 11       678.87               3
# ...            ...                ...          ...             ...
# 82954  654009201.0                  6      1252.52               1
# 82955  654197901.0                  9       478.84               2
# 82956  654387841.0                  3        27.22               1
# 82957  654580123.0                 15      1294.46               2
# 82958  654580244.0                 19      3436.90               2
#
#        service_purchases  other_purchases  days_since_first_transaction  \
# 0                      7                0                          1301
# 1                     15                0                          1242
# 2                      1                0                          1239
# 3                     10                0                          1068
# 4                      8                0                          1233
# ...                  ...              ...                           ...
# 82954                  5                0                          1308
# 82955                  7                0                          1298
# 82956                  2                0                          1059
# 82957                 13                0                          1238
# 82958                 16                1                          1185
#
#        days_since_last_transaction  days_since_first_tire_purchase  \
# 0                              198                           911.0
# 1                                3                           337.0
# 2                             1239                            -1.0
# 3                               65                          1068.0
# 4                              895                          1119.0
# ...                            ...                             ...
# 82954                          225                           225.0
# 82955                          147                           701.0
# 82956                          760                           760.0
# 82957                          118                           601.0
# 82958                           38                          1154.0
#
#        days_since_last_tire_purchase  vehicle_count  model_year_avg  region  \
# 0                              911.0              1             NaN     168
# 1                              337.0              3             NaN     274
# 2                               -1.0              1             NaN     244
# 3                             1068.0              2             NaN     168
# 4                              907.0              3             NaN      42
# ...                              ...            ...             ...     ...
# 82954                          225.0              1             NaN     212
# 82955                          316.0              1             NaN     230
# 82956                          760.0              1             NaN     255
# 82957                          448.0              2             NaN     194
# 82958                          455.0              3             NaN     108
#
#        tire_purchase_freq
# 0                0.000769
# 1                0.003221
# 2                0.000000
# 3                0.000936
# 4                0.002433
# ...                   ...
# 82954            0.000765
# 82955            0.001541
# 82956            0.000944
# 82957            0.001616
# 82958            0.001688
#
# [82959 rows x 14 columns]

# %% [markdown]
# #### looking at total_transaction

# %%
# 17K out of 83K people only did 1 transaction
# there are 19 people that had a unique number of transactions
print(validation_data['total_transaction'].value_counts().head(20))
print(validation_data['total_transaction'].value_counts().tail(20))
# Out:
# 1     17315
# 2     15339
# 3      8329
# 4      7369
# 5      5235
# 6      4438
# 7      3478
# 8      2902
# 9      2428
# 10     2173
# 11     1697
# 12     1536
# 13     1263
# 14     1105
# 15      931
# 16      865
# 17      727
# 18      645
# 19      585
# 20      487
# Name: total_transaction, dtype: int64
# 88     2
# 90     1
# 126    1
# 87     1
# 190    1
# 122    1
# 86     1
# 85     1
# 79     1
# 129    1
# 117    1
# 105    1
# 103    1
# 178    1
# 112    1
# 80     1
# 128    1
# 76     1
# 106    1
# 102    1
# Name: total_transaction, dtype: int64

# %%
# max number of total transactions was 190
# min number was 1
# confirmed no negative values
# not having 0 makes sense because then they would not be in the database
print(validation_data['total_transaction'].max())
print(validation_data['total_transaction'].min())
# Out:
# 190
# 1

# %%
# would hope our model would flag someone like him
# think he might also be highly ranked in sales total
validation_data[(validation_data['total_transaction'] == 190)]
# Out:
#          indiv_id  total_transaction  sales_total  tire_purchases  \
# 5161  256487427.0                190     13068.35              42
#
#       service_purchases  other_purchases  days_since_first_transaction  \
# 5161                147                1                          1309
#
#       days_since_last_transaction  days_since_first_tire_purchase  \
# 5161                           10                          1309.0
#
#       days_since_last_tire_purchase  vehicle_count  model_year_avg  store  \
# 5161                           70.0             94          2011.0   5126
#
#       tire_purchase_freq
# 5161            0.032086

# %% [markdown]
# #### looking at tire_purchases

# %%
# 38K people did not buy tires
# otherwise, most people only bought tires a few times
print(validation_data['tire_purchases'].value_counts().head(20))
print(validation_data['tire_purchases'].value_counts().tail(20))

# %%
# largest number a person bought tires was 52
# no negative numbers
print(validation_data['tire_purchases'].max())
print(validation_data['tire_purchases'].min())
# Out:
# 52
# 0

# %%
# look at a constant tire buyer
validation_data[(validation_data['tire_purchases'] == 52)]
# Out:
#           indiv_id  total_transaction  sales_total  tire_purchases  \
# 42235  291628093.0                119      9240.26              52
#
#        service_purchases  other_purchases  days_since_first_transaction  \
# 42235                 66                1                          1310
#
#        days_since_last_transaction  days_since_first_tire_purchase  \
# 42235                            5                          1310.0
#
#        days_since_last_tire_purchase  vehicle_count  model_year_avg  store  \
# 42235                            6.0              9             NaN  14443
#
#        tire_purchase_freq
# 42235            0.039695

# %% [markdown]
# #### looking at services_purchases

# %%
# the majority of customers had 1 service transaction
print(validation_data['service_purchases'].value_counts().head(20))
print(validation_data['service_purchases'].value_counts().tail(20))
# Out:
# 1     25511
# 2     13639
# 3      8854
# 4      6486
# 5      4826
# 6      3760
# 7      3101
# 8      2558
# 9      2032
# 10     1629
# 11     1434
# 12     1188
# 13      991
# 14      890
# 15      722
# 16      654
# 17      584
# 18      495
# 19      444
# 20      313
# Name: service_purchases, dtype: int64
# 93     2
# 147    2
# 72     2
# 121    1
# 90     1
# 103    1
# 100    1
# 99     1
# 97     1
# 94     1
# 91     1
# 89     1
# 84     1
# 82     1
# 77     1
# 76     1
# 75     1
# 71     1
# 69     1
# 63     1
# Name: service_purchases, dtype: int64

# %%
# values in range of the max and min total transactions
# no negative values
print(validation_data['service_purchases'].max())
print(validation_data['service_purchases'].min())
# Out:
# 147
# 0

# %% [markdown]
# #### looking at other_purchases

# %%
# only a few values for other purchases
# max is 32 and min is 0
print(validation_data['other_purchases'].value_counts().head(20))
print(validation_data['other_purchases'].value_counts().tail(20))
# Out:
# 0     79538
# 1      2861
# 2       326
# 3       102
# 4        47
# 5        28
# 6        19
# 8         9
# 11        7
# 7         6
# 9         4
# 10        3
# 12        2
# 14        2
# 16        2
# 17        1
# 19        1
# 32        1
# Name: other_purchases, dtype: int64
# 0     79538
# 1      2861
# 2       326
# 3       102
# 4        47
# 5        28
# 6        19
# 8         9
# 11        7
# 7         6
# 9         4
# 10        3
# 12        2
# 14        2
# 16        2
# 17        1
# 19        1
# 32        1
# Name: other_purchases, dtype: int64

# %% [markdown]
# #### looking at sales_total

# %%
# histogram for the sales column
# see that most people are spending less than 1000
# very few people are spending over 5000
validation_data.hist(column='sales_total', bins=40, range=(0, 5000))
# Out:
# array([[<AxesSubplot:title={'center':'sales_total'}>]], dtype=object)

# %%
# these are something to think about
# 345 people have negative sales values
validation_data[(validation_data['sales_total'] < 0)]
# Out:
#           indiv_id  total_transaction  sales_total  tire_purchases  \
# 193    251795482.0                  3        -8.02               0
# 379    251959867.0                  1        -5.63               0
# 1867   253386449.0                  1        -3.02               0
# 2120   253636667.0                  1        -2.95               0
# 2169   253664977.0                  1        -6.16               0
# ...            ...                ...          ...             ...
# 81860  555471302.0                  1        -0.13               0
# 81933  555835465.0                  3       -12.84               0
# 81970  555985098.0                  1        -0.04               0
# 82282  561027519.0                  1        -1.69               0
# 82917  635333437.0                  1        -9.54               0
#
#        service_purchases  other_purchases  days_since_first_transaction  \
# 193                    3                0                           798
# 379                    1                0                          1266
# 1867                   1                0                          1236
# 2120                   1                0                          1219
# 2169                   1                0                          1205
# ...                  ...              ...                           ...
# 81860                  1                0                            26
# 81933                  3                0                            22
# 81970                  1                0                            19
# 82282                  1                0                             1
# 82917                  1                0                          1293
#
#        days_since_last_transaction  days_since_first_tire_purchase  \
# 193                            121                            -1.0
# 379                           1266                            -1.0
# 1867                          1236                            -1.0
# 2120                          1219                            -1.0
# 2169                          1205                            -1.0
# ...                            ...                             ...
# 81860                           26                            -1.0
# 81933                            8                            -1.0
# 81970                           19                            -1.0
# 82282                            1                            -1.0
# 82917                         1293                            -1.0
#
#        days_since_last_tire_purchase  vehicle_count  model_year_avg   store  \
# 193                             -1.0              2             NaN  784285
# 379                             -1.0              1             NaN    5061
# 1867                            -1.0              1             NaN  533521
# 2120                            -1.0              1             NaN  227603
# 2169                            -1.0              1             NaN  290689
# ...                              ...            ...             ...     ...
# 81860                           -1.0              1             NaN   12106
# 81933                           -1.0              2             NaN    5967
# 81970                           -1.0              1             NaN  442607
# 82282                           -1.0              1             NaN  793851
# 82917                           -1.0              1          2011.0   14133
#
#        tire_purchase_freq
# 193                   0.0
# 379                   0.0
# 1867                  0.0
# 2120                  0.0
# 2169                  0.0
# ...                   ...
# 81860                 0.0
# 81933                 0.0
# 81970                 0.0
# 82282                 0.0
# 82917                 0.0
#
# [345 rows x 14 columns]

# %%
# investigate 
# dont think these make sense
mega_table[(mega_table['indiv_id'] == 251795482.0)]
# Out:
#          unnamed_0_x store_id    tran_id        date  article_id     indiv_id  \
# 28869          28870   784285  990103960  2018-07-03     7003186  251795482.0
# 28870          28871   784285  990103870  2018-07-02     7046930  251795482.0
# 28871          28872   784285  990103960  2018-07-03     7047627  251795482.0
# 28872          28873   784285  990103870  2018-07-02     7022373  251795482.0
# 28873          28874   784285  990103960  2018-07-03     7005505  251795482.0
# 28874          28875   784285  990103870  2018-07-02     7003189  251795482.0
# 28875          28876   784285  990103870  2018-07-02     7003348  251795482.0
# 28876          28877   784285  990103870  2018-07-02     7010962  251795482.0
# 1650860      1650861    13102  991903300  2016-08-25     7004302  251795482.0
# 1650861      1650862    13102  991903300  2016-08-25     7001119  251795482.0
# 1650862      1650863    13102  991903300  2016-08-25     7028789  251795482.0
# 1650863      1650864    13102  991903300  2016-08-25     7002937  251795482.0
# 1650864      1650865    13102  991903300  2016-08-25     7004302  251795482.0
# 1650865      1650866    13102  991903300  2016-08-25     7002909  251795482.0
#
#          vehicle_id  units   sales  prod_group_code  ... unnamed_0_y  \
# 28869     967917425    0.0    0.00              4.0  ...       32644
# 28870     967917425    0.0    0.00              4.0  ...       32644
# 28871     967917425    0.0 -247.00              4.0  ...       32644
# 28872     967917425    0.0   98.99              4.0  ...       32644
# 28873     967917425    0.0    0.00              4.0  ...       32644
# 28874     967917425    1.0   70.00              4.0  ...       32644
# 28875     967917425    0.0   60.00              4.0  ...       32644
# 28876     967917425    0.0    0.00              4.0  ...       32644
# 1650860   950801158    0.0    0.00              4.0  ...       32644
# 1650861   950801158    0.0    0.00              4.0  ...       32644
# 1650862   950801158    0.0   21.99              4.0  ...       32644
# 1650863   950801158    0.0    0.00              4.0  ...       32644
# 1650864   950801158    0.0  -12.00              4.0  ...       32644
# 1650865   950801158    0.0    0.00              4.0  ...       32644
#
#          email_optin_ind ah1_res_bus_indc  supp1_bus_pander unnamed_0  make  \
# 28869                  Y                R                 N       NaN   NaN
# 28870                  Y                R                 N       NaN   NaN
# 28871                  Y                R                 N       NaN   NaN
# 28872                  Y                R                 N       NaN   NaN
# 28873                  Y                R                 N       NaN   NaN
# 28874                  Y                R                 N       NaN   NaN
# 28875                  Y                R                 N       NaN   NaN
# 28876                  Y                R                 N       NaN   NaN
# 1650860                Y                R                 N       NaN   NaN
# 1650861                Y                R                 N       NaN   NaN
# 1650862                Y                R                 N       NaN   NaN
# 1650863                Y                R                 N       NaN   NaN
# 1650864                Y                R                 N       NaN   NaN
# 1650865                Y                R                 N       NaN   NaN
#
#         model sub_model model_year month_year
# 28869     NaN       NaN        NaN    2018-07
# 28870     NaN       NaN        NaN    2018-07
# 28871     NaN       NaN        NaN    2018-07
# 28872     NaN       NaN        NaN    2018-07
# 28873     NaN       NaN        NaN    2018-07
# 28874     NaN       NaN        NaN    2018-07
# 28875     NaN       NaN        NaN    2018-07
# 28876     NaN       NaN        NaN    2018-07
# 1650860   NaN       NaN        NaN    2016-08
# 1650861   NaN       NaN        NaN    2016-08
# 1650862   NaN       NaN        NaN    2016-08
# 1650863   NaN       NaN        NaN    2016-08
# 1650864   NaN       NaN        NaN    2016-08
# 1650865   NaN       NaN        NaN    2016-08
#
# [14 rows x 34 columns]

# %%
# people are getting refunded for more than they paid
mega_table[(mega_table['indiv_id'] == 251959867.0)]
# Out:
#         unnamed_0_x store_id    tran_id        date  article_id     indiv_id  \
# 448330       448331     5061  991042380  2015-05-15     7001718  251959867.0
# 448331       448332     5061  991042380  2015-05-15     7001122  251959867.0
# 448332       448333     5061  991042380  2015-05-15     7046930  251959867.0
# 448333       448334     5061  991042380  2015-05-15     7087890  251959867.0
# 448334       448335     5061  991042380  2015-05-15     7041556  251959867.0
# 448335       448336     5061  991042380  2015-05-15     7008824  251959867.0
# 448336       448337     5061  991042380  2015-05-15     7020435  251959867.0
#
#         vehicle_id  units   sales  prod_group_code  ... unnamed_0_y  \
# 448330   913517968    0.0   -5.63              4.0  ...       65247
# 448331   913517968    0.0    0.00              4.0  ...       65247
# 448332   913517968    0.0    0.00              4.0  ...       65247
# 448333   913517968    0.0 -125.98              4.0  ...       65247
# 448334   913517968    0.0    0.00              4.0  ...       65247
# 448335   913517968    1.0    0.00              4.0  ...       65247
# 448336   913517968    2.0  125.98              4.0  ...       65247
#
#         email_optin_ind ah1_res_bus_indc  supp1_bus_pander unnamed_0  make  \
# 448330                Y                R                 N       NaN   NaN
# 448331                Y                R                 N       NaN   NaN
# 448332                Y                R                 N       NaN   NaN
# 448333                Y                R                 N       NaN   NaN
# 448334                Y                R                 N       NaN   NaN
# 448335                Y                R                 N       NaN   NaN
# 448336                Y                R                 N       NaN   NaN
#
#        model sub_model model_year month_year
# 448330   NaN       NaN        NaN    2015-05
# 448331   NaN       NaN        NaN    2015-05
# 448332   NaN       NaN        NaN    2015-05
# 448333   NaN       NaN        NaN    2015-05
# 448334   NaN       NaN        NaN    2015-05
# 448335   NaN       NaN        NaN    2015-05
# 448336   NaN       NaN        NaN    2015-05
#
# [7 rows x 34 columns]

# %% [markdown]
# #### looking at vehicle_count

# %%
# most people only own 1 or 2 cars
print(validation_data['vehicle_count'].value_counts().head(20))
print(validation_data['vehicle_count'].value_counts().tail(20))
# Out:
# 1     48658
# 2     19356
# 3      8164
# 4      3529
# 5      1597
# 6       794
# 7       384
# 8       203
# 9        90
# 10       61
# 11       38
# 14       18
# 12       16
# 13       11
# 17        7
# 19        6
# 18        4
# 16        4
# 15        4
# 20        2
# Name: vehicle_count, dtype: int64
# 12    16
# 13    11
# 17     7
# 19     6
# 18     4
# 16     4
# 15     4
# 20     2
# 28     2
# 79     1
# 21     1
# 22     1
# 24     1
# 25     1
# 26     1
# 94     1
# 33     1
# 35     1
# 36     1
# 42     1
# Name: vehicle_count, dtype: int64

# %%
# no zeroes or negatives
print(validation_data['vehicle_count'].max())
print(validation_data['vehicle_count'].min())
# Out:
# 94
# 1

# %%
# guy who has 94 cars has the highest transactions
validation_data[(validation_data['vehicle_count'] == 94)]
# Out:
#          indiv_id  total_transaction  sales_total  tire_purchases  \
# 5161  256487427.0                190     13068.35              42
#
#       service_purchases  other_purchases  days_since_first_transaction  \
# 5161                147                1                          1309
#
#       days_since_last_transaction  days_since_first_tire_purchase  \
# 5161                           10                          1309.0
#
#       days_since_last_tire_purchase  vehicle_count  model_year_avg  store  \
# 5161                           70.0             94          2011.0   5126
#
#       tire_purchase_freq
# 5161            0.032086

# %%
# can see from the chart that man is an outlier
# the only other person that has more than 60 cars does not have nearly as many transactions
# but there is someone that has close to that number of transactions that only has a few cars
validation_data.plot(x='vehicle_count', y='total_transaction', style='o')
# Out:
# <AxesSubplot:xlabel='vehicle_count'>

# %% [markdown]
# #### looking at model_year

# %%
# model year feature the one with very little data - only 521 entries
validation_data[(validation_data['model_year_avg'] > 0)]
# Out:
#           indiv_id  total_transaction  sales_total  tire_purchases  \
# 328    251892059.0                  9      1760.74               2
# 403    251974300.0                 12      1650.58               2
# 470    252025076.0                  8      1440.72               4
# 637    252178816.0                 25      1265.25               5
# 839    252387414.0                 14      2831.58               4
# ...            ...                ...          ...             ...
# 82678  605772273.0                 32      3926.14               7
# 82722  610223763.0                 11      1499.96               4
# 82783  614600916.0                 15      2196.57               4
# 82792  615125533.0                 35      6485.02               3
# 82917  635333437.0                  1        -9.54               0
#
#        service_purchases  other_purchases  days_since_first_transaction  \
# 328                    7                0                          1283
# 403                   10                0                          1223
# 470                    4                0                          1278
# 637                   16                4                          1262
# 839                   10                0                          1061
# ...                  ...              ...                           ...
# 82678                 25                0                          1258
# 82722                  7                0                           867
# 82783                 11                0                          1248
# 82792                 32                0                          1247
# 82917                  1                0                          1293
#
#        days_since_last_transaction  days_since_first_tire_purchase  \
# 328                             36                           701.0
# 403                             54                          1214.0
# 470                             47                          1278.0
# 637                             94                          1262.0
# 839                            417                          1061.0
# ...                            ...                             ...
# 82678                            3                          1001.0
# 82722                           41                           867.0
# 82783                           23                          1140.0
# 82792                           73                           937.0
# 82917                         1293                            -1.0
#
#        days_since_last_tire_purchase  vehicle_count  model_year_avg   store  \
# 328                             39.0              3     2004.000000  353858
# 403                           1207.0              3     2007.000000    6882
# 470                             47.0              3     2013.000000  646067
# 637                             94.0              4     2000.000000  533416
# 839                            614.0              5     2003.000000    5460
# ...                              ...            ...             ...     ...
# 82678                           72.0              9     2013.000000  317132
# 82722                          177.0              1     2014.000000  336252
# 82783                          358.0              5     2004.571429    6599
# 82792                          523.0              6     2015.000000  679712
# 82917                           -1.0              1     2011.000000   14133
#
#        tire_purchase_freq
# 328              0.001559
# 403              0.001635
# 470              0.003130
# 637              0.003962
# 839              0.003770
# ...                   ...
# 82678            0.005564
# 82722            0.004614
# 82783            0.003205
# 82792            0.002406
# 82917            0.000000
#
# [521 rows x 14 columns]

# %%
# histogram is within the expected values
validation_data.hist(column='model_year_avg', bins=40)
# Out:
# array([[<AxesSubplot:title={'center':'model_year_avg'}>]], dtype=object)

# %% [markdown]
# #### looking at store

# %%
# large variety in the stores
# only 181 transactions are at the same store
print(validation_data['region'].value_counts().head(20))
print(validation_data['region'].value_counts().tail(20))
# Out:
# 0      12735
# 17      2281
# 59      2251
# 49      2031
# 109     1560
# 143     1261
# 282     1163
# 226     1159
# 225     1152
# 106     1055
# 255     1051
# 274     1045
# 166     1035
# 154      936
# 47       922
# 220      916
# 265      912
# 211      907
# 83       878
# 216      872
# Name: region, dtype: int64
# 164    25
# 176    25
# 258    25
# 183    24
# 156    23
# 207    23
# 229    22
# 8      22
# 276    21
# 6      21
# 227    19
# 266    19
# 234    18
# 301    17
# 267    16
# 97     15
# 215    14
# 14     10
# 43      9
# 205     9
# Name: region, dtype: int64

# %%
# no zeroes or negatives for store value
print(validation_data['region'].max())
print(validation_data['region'].min())
# Out:
# 310
# 0

# %%
# histogram is within the expected values
# 0 is a placeholder value for region of comma
validation_data.hist(column='region', bins=40)
# Out:
# array([[<AxesSubplot:title={'center':'region'}>]], dtype=object)

# %% [markdown]
# #### looking at tire_purchase_freq

# %%
# 1.0 seems very odd 
print(validation_data['tire_purchase_freq'].max())
print(validation_data['tire_purchase_freq'].min())
# Out:
# 1.0
# 0.0

# %%
# donot know if we should remove these people
# they just bought tires so it looks like they have a really high freq
validation_data[(validation_data['tire_purchase_freq'] > 0.2)]
# Out:
#           indiv_id  total_transaction  sales_total  tire_purchases  \
# 8694   259728268.0                  2       502.98               1
# 34805  284712754.0                  2       206.96               1
# 70185  437578297.0                  2      1166.40               1
# 82155  559832440.0                  3       321.88               2
# 82181  560586085.0                  2       688.79               1
# 82217  560697247.0                  2       737.50               1
# 82225  560754048.0                  2       150.32               1
# 82226  560754237.0                  2      1092.18               1
# 82228  560755133.0                  2       180.58               1
# 82230  560756005.0                  2       274.91               1
# 82234  560760392.0                  2      1077.95               1
# 82236  560761522.0                  2       689.80               1
# 82237  560761616.0                  2       207.96               1
# 82241  560828409.0                  2       202.36               1
# 82245  560829849.0                  2       773.91               1
# 82247  560832639.0                  2       118.88               1
# 82254  560836078.0                  2        60.98               1
# 82259  560913980.0                  2       419.84               1
# 82260  560915486.0                  2       736.83               1
# 82262  560921191.0                  2       570.39               1
# 82263  560921854.0                  2       237.96               1
# 82266  560923033.0                  2       176.76               1
# 82268  560935710.0                  2       559.91               1
# 82270  560939329.0                  2       680.87               1
# 82275  561007136.0                  2       155.50               1
#
#        service_purchases  other_purchases  days_since_first_transaction  \
# 8694                   1                0                             1
# 34805                  1                0                             3
# 70185                  1                0                             4
# 82155                  1                0                             7
# 82181                  1                0                             4
# 82217                  1                0                             4
# 82225                  1                0                             4
# 82226                  1                0                             4
# 82228                  1                0                             4
# 82230                  1                0                             4
# 82234                  1                0                             4
# 82236                  1                0                             4
# 82237                  1                0                             4
# 82241                  1                0                             3
# 82245                  1                0                             2
# 82247                  1                0                             2
# 82254                  1                0                             2
# 82259                  1                0                             2
# 82260                  1                0                             2
# 82262                  1                0                             2
# 82263                  1                0                             2
# 82266                  1                0                             2
# 82268                  1                0                             2
# 82270                  1                0                             2
# 82275                  1                0                             1
#
#        days_since_last_transaction  days_since_first_tire_purchase  \
# 8694                             1                             1.0
# 34805                            3                             3.0
# 70185                            4                             4.0
# 82155                            7                             7.0
# 82181                            4                             4.0
# 82217                            4                             4.0
# 82225                            4                             4.0
# 82226                            4                             4.0
# 82228                            4                             4.0
# 82230                            4                             4.0
# 82234                            4                             4.0
# 82236                            4                             4.0
# 82237                            4                             4.0
# 82241                            3                             3.0
# 82245                            2                             2.0
# 82247                            2                             2.0
# 82254                            2                             2.0
# 82259                            2                             2.0
# 82260                            2                             2.0
# 82262                            2                             2.0
# 82263                            2                             2.0
# 82266                            2                             2.0
# 82268                            2                             2.0
# 82270                            2                             2.0
# 82275                            1                             1.0
#
#        days_since_last_tire_purchase  vehicle_count  model_year_avg   store  \
# 8694                             1.0              1             NaN   21709
# 34805                            3.0              1             NaN    6009
# 70185                            4.0              1             NaN  326687
# 82155                            7.0              2             NaN  784290
# 82181                            4.0              1             NaN   17434
# 82217                            4.0              1             NaN  348713
# 82225                            4.0              1             NaN   46485
# 82226                            4.0              1             NaN   23884
# 82228                            4.0              1             NaN   19739
# 82230                            4.0              1             NaN   29467
# 82234                            4.0              1             NaN   20494
# 82236                            4.0              1             NaN   15563
# 82237                            4.0              1             NaN  120332
# 82241                            3.0              1             NaN  330664
# 82245                            2.0              1             NaN  458805
# 82247                            2.0              1             NaN   23612
# 82254                            2.0              1             NaN   16780
# 82259                            2.0              1             NaN  267356
# 82260                            2.0              1             NaN  793861
# 82262                            2.0              1             NaN   19305
# 82263                            2.0              1             NaN   28754
# 82266                            2.0              1             NaN  122157
# 82268                            2.0              1             NaN   23264
# 82270                            2.0              1             NaN  244208
# 82275                            1.0              1             NaN  517585
#
#        tire_purchase_freq
# 8694             1.000000
# 34805            0.333333
# 70185            0.250000
# 82155            0.285714
# 82181            0.250000
# 82217            0.250000
# 82225            0.250000
# 82226            0.250000
# 82228            0.250000
# 82230            0.250000
# 82234            0.250000
# 82236            0.250000
# 82237            0.250000
# 82241            0.333333
# 82245            0.500000
# 82247            0.500000
# 82254            0.500000
# 82259            0.500000
# 82260            0.500000
# 82262            0.500000
# 82263            0.500000
# 82266            0.500000
# 82268            0.500000
# 82270            0.500000
# 82275            1.000000

# %%
validation_data.hist(column='tire_purchase_freq', bins=40)
# Out:
# array([[<AxesSubplot:title={'center':'tire_purchase_freq'}>]],
#       dtype=object)

# %% [markdown]
# #### looking at monthly variables

# %%
data = [['January', validation_data['jan'].sum()], ['February', validation_data['feb'].sum()], ['March', validation_data['mar'].sum()], ['April', validation_data['apr'].sum()], ['May', validation_data['may'].sum()], ['June', validation_data['jun'].sum()], ['July', validation_data['jul'].sum()], ['August', validation_data['aug'].sum()], ['September', validation_data['sep'].sum()], ['October', validation_data['oct'].sum()], ['November', validation_data['nov'].sum()], ['December', validation_data['dec'].sum()]]
month_plot = pd.DataFrame(data, columns = ['Month', 'Count of Total Tire Purchases'])

month_plot

month_plot.plot.bar(x='Month', y='Count of Total Tire Purchases', ylim=(0,9000))

# %% [markdown]
# Ideas for new features
# 1. How many months out of the time period did the person buy tires (is this captured in the frequency variable)?
# 2. I dont know if the model will already do this but percent tire sales / total sales?
# 3. Is this already done - tires divided by number of cars?
