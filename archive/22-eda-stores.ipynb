# %% [markdown]
# # 22-eda-stores
# > Exploratory data analysis - stores
#
# This is EDA based around the stores table and how it relates to the rest of the Bridgestone dataset.

# %%
# load modules
import seaborn as sns

# %%
store.shape
# Out:
# (2813, 4)

# %%
store.head()
# Out:
#   store_id state_code zip_code  msa
# 0   244240         NE    68134  NaN
# 1   244233         MO    64151  NaN
# 2   227602         KY    40272  NaN
# 3   227603         KY    40219  NaN
# 4   232365         IN    46142  NaN

# %%
pd.value_counts(store.dtypes)
# Out:
# object    4
# dtype: int64

# %% [markdown]
# ## Store Stats

# %% [markdown]
# - 2,813 stores
# - no missing store_id, state_code, or zip_code
# - 504 missing msa ("metropolitan statistical area" - a city and its surrounding communities)
# - state with most stores: Florida (330)
# - msa with most stores: Chicago (76)

# %%
store.describe(exclude="number")
# Out:
#        store_id state_code zip_code         msa
# count      2813       2813     2813        2309
# unique     2813         48     2374         321
# top      244240         FL    37027  CHICAGO,IL
# freq          1        330        5          76

# %%
# check for duplicates
print(store.duplicated().sum())
# Out:
# 0

# %%
# check for missing values
store.isna().sum()
# Out:
# store_id        0
# state_code      0
# zip_code        0
# msa           504
# dtype: int64

# %%
# check stores with missing msa
store[store['msa'].isna()]
# Out:
#      store_id state_code zip_code  msa
# 0      244240         NE    68134  NaN
# 1      244233         MO    64151  NaN
# 2      227602         KY    40272  NaN
# 3      227603         KY    40219  NaN
# 4      232365         IN    46142  NaN
# ...       ...        ...      ...  ...
# 2802   244213         MN    56001  NaN
# 2809   246650         CO    80002  NaN
# 2810   400645         NV    89410  NaN
# 2811   794382         SC    29455  NaN
# 2812   232364         IN    46254  NaN
#
# [504 rows x 4 columns]

# %% [markdown]
# ## Sales at Stores

# %%
mega_table.shape
# Out:
# (4000504, 33)

# %%
mega_table.head()
# Out:
#    unnamed_0_x store_id    tran_id        date  article_id     indiv_id  \
# 0            1   337934  990994590  2018-07-23     7001647  318422234.0
# 1            2   337934  990994590  2018-07-23     7001715  318422234.0
# 2            3   337934  990994590  2018-07-23     7096547  318422234.0
# 3            4   337934  990994590  2018-07-23     7001647  318422234.0
# 4            5   337934  990994590  2018-07-23     7001715  318422234.0
#
#    vehicle_id  units  sales  prod_group_code  ...         msa  unnamed_0_y  \
# 0   944814728    0.0  -8.55              4.0  ...  HAGERSTOWN     11239886
# 1   944814728    0.0 -50.45              4.0  ...  HAGERSTOWN     11239886
# 2   944814728    0.0  10.00              4.0  ...  HAGERSTOWN     11239886
# 3   944814728    0.0   0.00              4.0  ...  HAGERSTOWN     11239886
# 4   944814728    0.0   0.00              4.0  ...  HAGERSTOWN     11239886
#
#   email_optin_ind  ah1_res_bus_indc supp1_bus_pander  unnamed_0 make model  \
# 0               Y                 R                N        NaN  NaN   NaN
# 1               Y                 R                N        NaN  NaN   NaN
# 2               Y                 R                N        NaN  NaN   NaN
# 3               Y                 R                N        NaN  NaN   NaN
# 4               Y                 R                N        NaN  NaN   NaN
#
#   sub_model model_year
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# 4       NaN        NaN
#
# [5 rows x 33 columns]

# %%
mega_table.columns
# Out:
# Index(['unnamed_0_x', 'store_id', 'tran_id', 'date', 'article_id', 'indiv_id',
#        'vehicle_id', 'units', 'sales', 'prod_group_code', 'prod_group_desc',
#        'category_code', 'category_desc', 'segment_code', 'segment_desc',
#        'class_code', 'class_desc', 'discount_flag', 'cross_section',
#        'aspect_ratio', 'rim_size', 'state_code', 'zip_code', 'msa',
#        'unnamed_0_y', 'email_optin_ind', 'ah1_res_bus_indc',
#        'supp1_bus_pander', 'unnamed_0', 'make', 'model', 'sub_model',
#        'model_year'],
#       dtype='object')

# %% [markdown]
# ### Sales Aggregates

# %% [markdown]
# #### By store

# %%
by_store = mega_table.groupby(['state_code','store_id']).agg(
    transactions_count = pd.NamedAgg(column='tran_id', aggfunc='nunique')
    ,products_sold_count = pd.NamedAgg(column='article_id', aggfunc='count')
    ,unique_customers = pd.NamedAgg(column='indiv_id', aggfunc='count')
    ,revenue_total = pd.NamedAgg(column='sales', aggfunc='sum')
)

by_store
# Out:
#                      transactions_count  products_sold_count  \
# state_code store_id
# AL         12335                    295                 3357
#            16616                    157                 1515
#            17558                    185                 2085
#            18910                    204                 2321
#            18929                    207                 2358
# ...                                 ...                  ...
# WV         5878                     225                 2237
#            6009                     177                 1629
#            8540                     246                 2135
# WY         23493                    112                 1045
#            655686                    51                  505
#
#                      unique_customers  revenue_total
# state_code store_id
# AL         12335                 3357       48597.65
#            16616                 1515       34045.43
#            17558                 2085       27849.01
#            18910                 2321       29958.35
#            18929                 2358       34329.94
# ...                               ...            ...
# WV         5878                  2237       43096.39
#            6009                  1629       28524.15
#            8540                  2135       42805.85
# WY         23493                 1045       19776.81
#            655686                 505       14059.23
#
# [2297 rows x 4 columns]

# %%
sns.displot(by_store, x="revenue_total", kind="kde")

# %% [markdown]
# #### By state

# %%
by_state = mega_table.groupby(['state_code']).agg(
    transactions_count = pd.NamedAgg(column='tran_id', aggfunc='nunique')
    ,products_sold_count = pd.NamedAgg(column='article_id', aggfunc='count')
    ,unique_customers = pd.NamedAgg(column='indiv_id', aggfunc='count')
    ,revenue_total = pd.NamedAgg(column='sales', aggfunc='sum')
).sort_values(by='revenue_total', ascending=False)

by_state
# Out:
#             transactions_count  products_sold_count  unique_customers  \
# state_code
# FL                       47034               520423            520423
# TX                       42068               395612            395612
# CA                       29870               299838            299838
# GA                       19474               198456            198456
# PA                       14613               164652            164652
# IL                       14055               150039            150039
# NC                       14708               148144            148144
# OK                       14029               110131            110131
# OH                       13065               135564            135564
# VA                       11380               111949            111949
# NJ                       10511               115090            115090
# TN                       11515               121370            121370
# NY                       10660               102412            102412
# MN                       10047               104927            104927
# MO                       10071               103915            103915
# CO                        8079                82965             82965
# CT                        8751                67949             67949
# MA                        7104                64763             64763
# SC                        8631                85117             85117
# WA                        7102                76805             76805
# AL                        8419                90913             90913
# IN                        7872                78339             78339
# WI                        6334                60635             60635
# MD                        6476                64962             64962
# AZ                        6632                73140             73140
# LA                        5346                44824             44824
# KS                        5658                54180             54180
# MI                        3839                38944             38944
# KY                        3383                32258             32258
# MS                        4061                38237             38237
# NV                        3573                36320             36320
# IA                        3344                31842             31842
# AR                        3119                26989             26989
# NE                        2888                28707             28707
# UT                        2620                24765             24765
# OR                        2031                17185             17185
# NM                        1880                18623             18623
# HI                        1818                16764             16764
# RI                        1559                14261             14261
# DE                        1282                13479             13479
# NH                         754                 7224              7224
# ND                         739                 6708              6708
# WV                         724                 6684              6684
# SD                         459                 3629              3629
# MT                         396                 4095              4095
# ID                         251                 2458              2458
# WY                         163                 1550              1550
# DC                         132                  967               967
#
#             revenue_total
# state_code
# FL             9783276.12
# TX             8160277.11
# CA             6404329.13
# GA             3671831.12
# PA             2815090.61
# IL             2542861.60
# NC             2542835.89
# OK             2504459.57
# OH             2337783.48
# VA             2227443.69
# NJ             2193769.59
# TN             2172433.03
# NY             2000947.27
# MN             1925806.14
# MO             1822059.79
# CO             1604651.76
# CT             1474903.27
# MA             1462842.43
# SC             1437087.83
# WA             1416695.69
# AL             1362410.15
# IN             1274409.59
# WI             1253435.64
# MD             1230930.50
# AZ             1186248.27
# LA             1075166.98
# KS              981290.85
# MI              749870.87
# KY              671918.77
# MS              657364.47
# NV              634778.83
# IA              606404.73
# AR              538469.97
# NE              498836.13
# UT              462349.23
# OR              362358.35
# NM              348438.61
# HI              318006.08
# RI              278228.58
# DE              218642.40
# NH              151105.04
# ND              147277.69
# WV              126161.60
# SD               84060.17
# MT               82531.81
# ID               45089.17
# WY               33836.04
# DC               20878.11

# %%
sns.displot(by_state, x="revenue_total", kind="kde")

# %% [markdown]
# #### By msa

# %%
by_msa = mega_table.groupby(['msa']).agg(
    transactions_count = pd.NamedAgg(column='tran_id', aggfunc='nunique')
    ,products_sold_count = pd.NamedAgg(column='article_id', aggfunc='count')
    ,unique_customers = pd.NamedAgg(column='indiv_id', aggfunc='count')
    ,revenue_total = pd.NamedAgg(column='sales', aggfunc='sum')
).sort_values(by='revenue_total', ascending=False)

by_msa
# Out:
#             transactions_count  products_sold_count  unique_customers  \
# msa
# DALLAS,TX                12813               113432            113432
# ATLANTA,GA               11820               115576            115576
# CHICAGO,IL               10263               109800            109800
# HOUSTON,TX                8940                78814             78814
# LOS ANGELE                5929                52680             52680
# ...                        ...                  ...               ...
# STEUBENVIL                  56                  670               670
# WATERLOO,I                  56                  586               586
# SHEBOYGAN,                  51                  461               461
# APPLETON                    48                  489               489
# PINE BLUFF                  43                  319               319
#
#             revenue_total
# msa
# DALLAS,TX      2412360.90
# ATLANTA,GA     2174687.10
# CHICAGO,IL     1867173.69
# HOUSTON,TX     1608201.04
# LOS ANGELE     1134037.39
# ...                   ...
# STEUBENVIL        9810.81
# WATERLOO,I        7638.96
# SHEBOYGAN,        7089.69
# APPLETON          7084.64
# PINE BLUFF        4359.64
#
# [311 rows x 4 columns]

# %%
sns.displot(by_msa, x="revenue_total", kind="kde")

# %% [markdown]
# ## Mapping

# %% [markdown]
# Zip -> Lat/Lon: https://pypi.org/project/pgeocode/
# <br>
# Plot: https://stackoverflow.com/questions/53233228/plot-latitude-longitude-from-csv-in-python-3-6
