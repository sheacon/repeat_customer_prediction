# %% [markdown]
# # 21-vehicle-eda
# > Exploratory data analysis on the vehicle variables

# %%
# import packages
import pandas as pd
import janitor
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# code to read data files and clean names
# copied from other notebook
individual_sample = pd.read_csv('sample_data/individual_sample.csv', sep = ',', skiprows=[1]).clean_names()
product = pd.read_csv('sample_data/product.csv', sep = '|', skiprows=[1]).clean_names()
sales_sample = pd.read_csv('sample_data/sales_data_sample.csv', sep = ',', skiprows=[1]).clean_names()
store = pd.read_csv('sample_data/store.csv', sep = '|', skiprows=[1]).clean_names()
vehicle_sample = pd.read_csv('sample_data/vehicle_sample.csv', sep = ',', skiprows=[1]).clean_names()

# %%
# code to combine the various csv files into one dataframe
# copied from other notebook
individual_sample = individual_sample.rename(columns = {'mzb_indiv_id':'indiv_id'})
mega_table = sales_sample.merge(product, on = 'article_id', how = 'left')
mega_table = mega_table.merge(store, on = 'store_id', how = 'left')
mega_table = mega_table.merge(individual_sample, on = 'indiv_id', how = 'left')
mega_table = mega_table.merge(vehicle_sample, on = 'vehicle_id', how = 'left')

# %% [markdown]
# The following code is investigating nulls in the dataset. The team discovered that vehicle_sample is only part of the vehicle ids that are in the full dataset in ACCRE. Therefore, the nulls are not representative of how the dataset will look when we join in ACCRE, but this is something to keep in mind as we work in ACCRE.

# %%
# for only a very, very small percentage <1% is the vehicle model not null
# only 15K rows out of the megatable that is 4 million
mega_table[mega_table.make.notnull()]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 11706          11707     22055  992297610  2018-07-20     7009759
# 11707          11708     22055  992297610  2018-07-20     7046930
# 11708          11709     22055  992297610  2018-07-20     7001671
# 11709          11710     22055  992297610  2018-07-20     7001671
# 11710          11711     22055  992297610  2018-07-20     7001671
# ...              ...       ...        ...         ...         ...
# 3999374      3999375    784285  990049860  2017-11-12     7034653
# 3999375      3999376    784285  990049860  2017-11-12     7034654
# 3999376      3999377    784285  990049860  2017-11-12     7029718
# 3999377      3999378    784285  990049860  2017-11-12     7001674
# 3999378      3999379    784285  990049860  2017-11-12     7001674
#
#             indiv_id  vehicle_id  units  sales  prod_group_code  ...  \
# 11706    265468928.0   969825968    1.0   7.00              4.0  ...
# 11707    265468928.0   969825968    0.0   0.00              4.0  ...
# 11708    265468928.0   969825968    0.0   0.00              4.0  ...
# 11709    265468928.0   969825968    0.0   0.00              4.0  ...
# 11710    265468928.0   969825968    0.0   0.00              4.0  ...
# ...              ...         ...    ...    ...              ...  ...
# 3999374  312008751.0   958640114    1.0  26.00              4.0  ...
# 3999375  312008751.0   958640114    1.0   0.52              4.0  ...
# 3999376  312008751.0   958640114    0.0   5.00              4.0  ...
# 3999377  312008751.0   958640114    0.0 -12.76              4.0  ...
# 3999378  312008751.0   958640114    0.0  -2.03              4.0  ...
#
#                 msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 11706    PHILADELPH,      2773019               Y                 R
# 11707    PHILADELPH,      2773019               Y                 R
# 11708    PHILADELPH,      2773019               Y                 R
# 11709    PHILADELPH,      2773019               Y                 R
# 11710    PHILADELPH,      2773019               Y                 R
# ...              ...          ...             ...               ...
# 3999374   PHOENIX,AZ     10404517               Y                 R
# 3999375   PHOENIX,AZ     10404517               Y                 R
# 3999376   PHOENIX,AZ     10404517               Y                 R
# 3999377   PHOENIX,AZ     10404517               Y                 R
# 3999378   PHOENIX,AZ     10404517               Y                 R
#
#         supp1_bus_pander   unnamed_0     make            model sub_model  \
# 11706                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11707                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11708                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11709                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11710                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# ...                  ...         ...      ...              ...       ...
# 3999374                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999375                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999376                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999377                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999378                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
#
#         model_year
# 11706       2018.0
# 11707       2018.0
# 11708       2018.0
# 11709       2018.0
# 11710       2018.0
# ...            ...
# 3999374     2017.0
# 3999375     2017.0
# 3999376     2017.0
# 3999377     2017.0
# 3999378     2017.0
#
# [15241 rows x 33 columns]

# %%
# almost all of the vehicle information is null
# almost all 4 million entries
mega_table.loc[mega_table['make'].isnull()]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 0                  1    337934  990994590  2018-07-23     7001647
# 1                  2    337934  990994590  2018-07-23     7001715
# 2                  3    337934  990994590  2018-07-23     7096547
# 3                  4    337934  990994590  2018-07-23     7001647
# 4                  5    337934  990994590  2018-07-23     7001715
# ...              ...       ...        ...         ...         ...
# 4000499      4000500    328307  991045250  2017-11-30     7006062
# 4000500      4000501    328307  991045250  2017-11-30     7001665
# 4000501      4000502    328307  991045250  2017-11-30     7006472
# 4000502      4000503    328307  991045250  2017-11-30     7005229
# 4000503      4000504    328307  991045250  2017-11-30     7005180
#
#             indiv_id  vehicle_id  units   sales  prod_group_code  ...  \
# 0        318422234.0   944814728    0.0   -8.55              4.0  ...
# 1        318422234.0   944814728    0.0  -50.45              4.0  ...
# 2        318422234.0   944814728    0.0   10.00              4.0  ...
# 3        318422234.0   944814728    0.0    0.00              4.0  ...
# 4        318422234.0   944814728    0.0    0.00              4.0  ...
# ...              ...         ...    ...     ...              ...  ...
# 4000499  287704505.0   961712384    0.0    0.00              4.0  ...
# 4000500  287704505.0   961712384    0.0    0.00              4.0  ...
# 4000501  287704505.0   961712384    0.0    0.00              4.0  ...
# 4000502  287704505.0   961712384    0.0  199.99              4.0  ...
# 4000503  287704505.0   961712384    0.0  -20.00              4.0  ...
#
#                 msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 0        HAGERSTOWN,     11239886               Y                 R
# 1        HAGERSTOWN,     11239886               Y                 R
# 2        HAGERSTOWN,     11239886               Y                 R
# 3        HAGERSTOWN,     11239886               Y                 R
# 4        HAGERSTOWN,     11239886               Y                 R
# ...              ...          ...             ...               ...
# 4000499   ST.LOUIS,M      7175807               Y                 R
# 4000500   ST.LOUIS,M      7175807               Y                 R
# 4000501   ST.LOUIS,M      7175807               Y                 R
# 4000502   ST.LOUIS,M      7175807               Y                 R
# 4000503   ST.LOUIS,M      7175807               Y                 R
#
#         supp1_bus_pander  unnamed_0 make model sub_model model_year
# 0                      N        NaN  NaN   NaN       NaN        NaN
# 1                      N        NaN  NaN   NaN       NaN        NaN
# 2                      N        NaN  NaN   NaN       NaN        NaN
# 3                      N        NaN  NaN   NaN       NaN        NaN
# 4                      N        NaN  NaN   NaN       NaN        NaN
# ...                  ...        ...  ...   ...       ...        ...
# 4000499                N        NaN  NaN   NaN       NaN        NaN
# 4000500                N        NaN  NaN   NaN       NaN        NaN
# 4000501                N        NaN  NaN   NaN       NaN        NaN
# 4000502                N        NaN  NaN   NaN       NaN        NaN
# 4000503                N        NaN  NaN   NaN       NaN        NaN
#
# [3985263 rows x 33 columns]

# %%
# confirming that join is working and that the vehicle ids that are blank in mega_table are not in vehicle_sample
# the below ids are in mega_table but not in vehicle_sample so vehicle columns are coming up null
# seems like most of the vehicle ids in the mega_table are not in vehicle_sample
vehicle_sample.loc[vehicle_sample['vehicle_id'] == 944814728]
vehicle_sample.loc[vehicle_sample['vehicle_id'] == 961712384]
# Out:
# Empty DataFrame
# Columns: [unnamed_0, vehicle_id, make, model, sub_model, model_year]
# Index: []

# %%
# saving the null and not null mega_table rows as different dataframes to investigate more
vehicle_null = mega_table.loc[mega_table['make'].isnull()]
vehicle_not_null = mega_table[mega_table.make.notnull()]

# %%
# confirm that all vehicle that have vehicle information are eligible individuals
# confirmed - same number of rows as vehicle_not_null
vehicle_not_null[(vehicle_not_null['ah1_res_bus_indc'] == 'R') & (vehicle_not_null['supp1_bus_pander'] == 'N') & (vehicle_not_null['email_optin_ind'] == 'Y')]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 11706          11707     22055  992297610  2018-07-20     7009759
# 11707          11708     22055  992297610  2018-07-20     7046930
# 11708          11709     22055  992297610  2018-07-20     7001671
# 11709          11710     22055  992297610  2018-07-20     7001671
# 11710          11711     22055  992297610  2018-07-20     7001671
# ...              ...       ...        ...         ...         ...
# 3999374      3999375    784285  990049860  2017-11-12     7034653
# 3999375      3999376    784285  990049860  2017-11-12     7034654
# 3999376      3999377    784285  990049860  2017-11-12     7029718
# 3999377      3999378    784285  990049860  2017-11-12     7001674
# 3999378      3999379    784285  990049860  2017-11-12     7001674
#
#             indiv_id  vehicle_id  units  sales  prod_group_code  ...  \
# 11706    265468928.0   969825968    1.0   7.00              4.0  ...
# 11707    265468928.0   969825968    0.0   0.00              4.0  ...
# 11708    265468928.0   969825968    0.0   0.00              4.0  ...
# 11709    265468928.0   969825968    0.0   0.00              4.0  ...
# 11710    265468928.0   969825968    0.0   0.00              4.0  ...
# ...              ...         ...    ...    ...              ...  ...
# 3999374  312008751.0   958640114    1.0  26.00              4.0  ...
# 3999375  312008751.0   958640114    1.0   0.52              4.0  ...
# 3999376  312008751.0   958640114    0.0   5.00              4.0  ...
# 3999377  312008751.0   958640114    0.0 -12.76              4.0  ...
# 3999378  312008751.0   958640114    0.0  -2.03              4.0  ...
#
#                 msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 11706    PHILADELPH,      2773019               Y                 R
# 11707    PHILADELPH,      2773019               Y                 R
# 11708    PHILADELPH,      2773019               Y                 R
# 11709    PHILADELPH,      2773019               Y                 R
# 11710    PHILADELPH,      2773019               Y                 R
# ...              ...          ...             ...               ...
# 3999374   PHOENIX,AZ     10404517               Y                 R
# 3999375   PHOENIX,AZ     10404517               Y                 R
# 3999376   PHOENIX,AZ     10404517               Y                 R
# 3999377   PHOENIX,AZ     10404517               Y                 R
# 3999378   PHOENIX,AZ     10404517               Y                 R
#
#         supp1_bus_pander   unnamed_0     make            model sub_model  \
# 11706                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11707                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11708                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11709                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# 11710                  N  27055276.0   TOYOTA  COROLLA IM BASE      Base
# ...                  ...         ...      ...              ...       ...
# 3999374                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999375                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999376                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999377                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
# 3999378                N  24039260.0  HYUNDAI     SONATA SPORT     Sport
#
#         model_year
# 11706       2018.0
# 11707       2018.0
# 11708       2018.0
# 11709       2018.0
# 11710       2018.0
# ...            ...
# 3999374     2017.0
# 3999375     2017.0
# 3999376     2017.0
# 3999377     2017.0
# 3999378     2017.0
#
# [15241 rows x 33 columns]

# %%
# only 933 of the transactions with vehicle numbers are tire purchases
vehicle_not_null[(vehicle_not_null['prod_group_code'] == 5.0)]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 20083          20084     14346  992305920  2018-07-21       14859
# 52474          52475    141593  991253080  2018-07-30     7040215
# 52476          52477    141593  991253080  2018-07-30       14910
# 52478          52479    141593  991253080  2018-07-30     7097709
# 52481          52482    141593  991253080  2018-07-30     7097709
# ...              ...       ...        ...         ...         ...
# 3976925      3976926     12335  992235480  2017-11-06     7097782
# 3976930      3976931     12335  992235480  2017-11-06       15284
# 3976933      3976934     12335  992235480  2017-11-06       15284
# 3989498      3989499     24554  991782810  2017-11-06     7097782
# 3989503      3989504     24554  991782810  2017-11-06      122613
#
#             indiv_id  vehicle_id  units   sales  prod_group_code  ...  \
# 20083    285341839.0   889606831    2.0  211.98              5.0  ...
# 52474    252178816.0   940456791    0.0   28.00              5.0  ...
# 52476    252178816.0   940456791    4.0  351.96              5.0  ...
# 52478    252178816.0   940456791    0.0   -1.45              5.0  ...
# 52481    252178816.0   940456791    0.0  -30.80              5.0  ...
# ...              ...         ...    ...     ...              ...  ...
# 3976925  269446334.0   925704379    0.0   40.30              5.0  ...
# 3976930  269446334.0   925704379    1.0   88.54              5.0  ...
# 3976933  269446334.0   925704379    1.0   88.54              5.0  ...
# 3989498  260937410.0   909556630    0.0    8.55              5.0  ...
# 3989503  260937410.0   909556630    1.0   58.99              5.0  ...
#
#                 msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 20083     MELBOURNE,      6707536               Y                 R
# 52474              ,       112325               Y                 R
# 52476              ,       112325               Y                 R
# 52478              ,       112325               Y                 R
# 52481              ,       112325               Y                 R
# ...              ...          ...             ...               ...
# 3976925  BIRMINGHAM,      3547138               Y                 R
# 3976930  BIRMINGHAM,      3547138               Y                 R
# 3976933  BIRMINGHAM,      3547138               Y                 R
# 3989498   BALTIMORE,      1874003               Y                 R
# 3989503   BALTIMORE,      1874003               Y                 R
#
#         supp1_bus_pander   unnamed_0      make                   model  \
# 20083                  N  16282251.0  CHRYSLER  TOWN & COUNTRY TOURING
# 52474                  N  21458449.0     BUICK         LESABRE LIMITED
# 52476                  N  21458449.0     BUICK         LESABRE LIMITED
# 52478                  N  21458449.0     BUICK         LESABRE LIMITED
# 52481                  N  21458449.0     BUICK         LESABRE LIMITED
# ...                  ...         ...       ...                     ...
# 3976925                N  18629866.0    TOYOTA              SIENNA XLE
# 3976930                N  18629866.0    TOYOTA              SIENNA XLE
# 3976933                N  18629866.0    TOYOTA              SIENNA XLE
# 3989498                N  13762690.0     HONDA               ACCORD LX
# 3989503                N  13762690.0     HONDA               ACCORD LX
#
#                sub_model model_year
# 20083            Touring     2007.0
# 52474            Limited     2000.0
# 52476            Limited     2000.0
# 52478            Limited     2000.0
# 52481            Limited     2000.0
# ...                  ...        ...
# 3976925        XLE (AWD)     2010.0
# 3976930        XLE (AWD)     2010.0
# 3976933        XLE (AWD)     2010.0
# 3989498  LX Coupe 4 Cyl.     2006.0
# 3989503  LX Coupe 4 Cyl.     2006.0
#
# [933 rows x 33 columns]

# %%
# 255K of the transactions without vehicle numbers are tire purchases
# over 3 million are not tire purchases
vehicle_null[(vehicle_null['prod_group_code'] == 5.0)]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 6                  7      9946  991604320  2018-07-24        1222
# 25                26      9946  991604320  2018-07-24     7097782
# 29                30     18929  992094320  2018-07-09     7091037
# 31                32     18929  992094320  2018-07-09     7097782
# 32                33     18929  992094320  2018-07-09       97606
# ...              ...       ...        ...         ...         ...
# 4000427      4000428      3247  991666570  2017-11-29        2379
# 4000484      4000485    328307  991045250  2017-11-30     7097155
# 4000485      4000486    328307  991045250  2017-11-30         463
# 4000487      4000488    328307  991045250  2017-11-30     7097782
# 4000488      4000489    328307  991045250  2017-11-30     7097156
#
#             indiv_id  vehicle_id  units   sales  prod_group_code  ...  \
# 6        318411709.0   971231537    4.0  793.96              5.0  ...
# 25       318411709.0   971231537    0.0  125.28              5.0  ...
# 29       315301745.0   968621013    0.0    0.00              5.0  ...
# 31       315301745.0   968621013    0.0   66.68              5.0  ...
# 32       315301745.0   968621013    4.0  459.96              5.0  ...
# ...              ...         ...    ...     ...              ...  ...
# 4000427  501009408.0   964840068    1.0   86.99              5.0  ...
# 4000484  287704505.0   961712384    0.0  -60.32              5.0  ...
# 4000485  287704505.0   961712384    4.0  831.96              5.0  ...
# 4000487  287704505.0   961712384    0.0  120.64              5.0  ...
# 4000488  287704505.0   961712384    0.0    0.00              5.0  ...
#
#                 msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 6        NON-MET MN,     11238794               Y                 R
# 25       NON-MET MN,     11238794               Y                 R
# 29       HUNTSVILLE,     10802981               Y                 R
# 31       HUNTSVILLE,     10802981               Y                 R
# 32       HUNTSVILLE,     10802981               Y                 R
# ...              ...          ...             ...               ...
# 4000427    BILOXI,MS     14724723               Y                 R
# 4000484   ST.LOUIS,M      7175807               Y                 R
# 4000485   ST.LOUIS,M      7175807               Y                 R
# 4000487   ST.LOUIS,M      7175807               Y                 R
# 4000488   ST.LOUIS,M      7175807               Y                 R
#
#         supp1_bus_pander  unnamed_0 make model sub_model model_year
# 6                      N        NaN  NaN   NaN       NaN        NaN
# 25                     N        NaN  NaN   NaN       NaN        NaN
# 29                     N        NaN  NaN   NaN       NaN        NaN
# 31                     N        NaN  NaN   NaN       NaN        NaN
# 32                     N        NaN  NaN   NaN       NaN        NaN
# ...                  ...        ...  ...   ...       ...        ...
# 4000427                N        NaN  NaN   NaN       NaN        NaN
# 4000484                N        NaN  NaN   NaN       NaN        NaN
# 4000485                N        NaN  NaN   NaN       NaN        NaN
# 4000487                N        NaN  NaN   NaN       NaN        NaN
# 4000488                N        NaN  NaN   NaN       NaN        NaN
#
# [254785 rows x 33 columns]

# %%
# investigate how many unique vehicles are in each table
# only 524 unique vehicles that are not null in the mega table
# 137K in the null table
# need to investigate the vehicle_id that is 1 in the null values
print(vehicle_not_null['vehicle_id'].value_counts())
print(vehicle_null['vehicle_id'].value_counts())
# Out:
# 902665104    394
# 923088511    225
# 919868543    203
# 916397609    200
# 924480617    182
#             ...
# 965751518      1
# 965687878      1
# 399775336      1
# 962716502      1
# 962180357      1
# Name: vehicle_id, Length: 524, dtype: int64
# 1            43517
# 911829775      795
# 887616532      781
# 939702173      762
# 946406473      712
#              ...
# 959930460        1
# 936445636        1
# 311411996        1
# 889230324        1
# 901770251        1
# Name: vehicle_id, Length: 137075, dtype: int64

# %%
# there are over 43K values that have 1 as the vehicle id
# suggest deleting these values from the dataframe as this seems to be a filler value with no actual vehicle information
# 11K of the 43K are tire purchases which we are interested in
print(mega_table.loc[mega_table['vehicle_id'] == 1].shape)
print(mega_table.loc[(mega_table['vehicle_id'] == 1) & (mega_table['prod_group_code'] == 5)].shape)
# Out:
# (43517, 33)
# (11032, 33)

# %%
# out of the 524 unique vehicle ids in the data thathas vehicle information, there are 521 unique people
print(vehicle_not_null['indiv_id'].nunique())
print(vehicle_not_null['vehicle_id'].nunique())
# Out:
# 521
# 524

# %%
# This means that 
# only 3 people have more than one car out of the 521 people that do not have null vehicle information
# all 3 people have 2 cars 
indiv_by_vehicle = vehicle_not_null.groupby(['indiv_id'])['vehicle_id'].nunique().reset_index()
print(indiv_by_vehicle.loc[indiv_by_vehicle['vehicle_id'] > 1])
# Out:
#         indiv_id  vehicle_id
# 30   255446434.0           2
# 38   256487427.0           2
# 518  614600916.0           2

# %%
# example of information for one of the people that has two cars
# they bought tires only once for their first car
# all other purchases are product code 4
vehicle_not_null.loc[vehicle_not_null['indiv_id'] == indiv_by_vehicle.iloc[38][0]]
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 1672498      1672499     21431  991522430  2016-08-21     7015016
# 1672501      1672502     21431  991522430  2016-08-21       85961
# 1672533      1672534     21431  991522430  2016-08-21     7008026
# 1672535      1672536     21431  991522430  2016-08-21     7046930
# 1672537      1672538     21431  991521350  2016-08-20     7046930
# 1672549      1672550     21431  991522430  2016-08-21     7008195
# 1672550      1672551     21431  991521350  2016-08-20     7004578
# 1672577      1672578     21431  991521350  2016-08-20     7004584
# 1672580      1672581     21431  991521350  2016-08-20     7005333
# 2944814      2944815     21431  991761460  2018-10-05     7003381
# 2944819      2944820     21431  991761460  2018-10-05     7001674
# 2944820      2944821     21431  991761460  2018-10-05     7001674
# 2944821      2944822     21431  991761460  2018-10-05     7001123
# 2944822      2944823     21431  991761460  2018-10-05     7001674
# 2944823      2944824     21431  991761460  2018-10-05     7001674
# 2944824      2944825     21431  991761460  2018-10-05     7046930
# 2944825      2944826     21431  991761460  2018-10-05     7003355
# 2944826      2944827     21431  991761460  2018-10-05     7006949
# 2944827      2944828     21431  991761460  2018-10-05     7034622
# 2944828      2944829     21431  991761460  2018-10-05     7012935
#
#             indiv_id  vehicle_id  units   sales  prod_group_code  ...  \
# 1672498  256487427.0   950637235    0.0    0.00              4.0  ...
# 1672501  256487427.0   950637235    2.0  160.18              5.0  ...
# 1672533  256487427.0   950637235    0.0    0.00              4.0  ...
# 1672535  256487427.0   950637235    0.0    0.00              4.0  ...
# 1672537  256487427.0   950637235    0.0    0.00              4.0  ...
# 1672549  256487427.0   950637235    0.0    0.00              4.0  ...
# 1672550  256487427.0   950637235    0.0   84.99              4.0  ...
# 1672577  256487427.0   950637235    0.0  -25.00              4.0  ...
# 1672580  256487427.0   950637235    0.0    0.00              4.0  ...
# 2944814  256487427.0   981248430    0.0   -1.27              4.0  ...
# 2944819  256487427.0   981248430    0.0  -15.97              4.0  ...
# 2944820  256487427.0   981248430    0.0   -0.76              4.0  ...
# 2944821  256487427.0   981248430    0.0    0.00              4.0  ...
# 2944822  256487427.0   981248430    0.0    0.00              4.0  ...
# 2944823  256487427.0   981248430    0.0    0.00              4.0  ...
# 2944824  256487427.0   981248430    0.0    0.00              4.0  ...
# 2944825  256487427.0   981248430    0.0    5.00              4.0  ...
# 2944826  256487427.0   981248430    1.0    4.99              4.0  ...
# 2944827  256487427.0   981248430    0.0   58.00              4.0  ...
# 2944828  256487427.0   981248430    0.0    0.00              4.0  ...
#
#               msa_  unnamed_0_y email_optin_ind  ah1_res_bus_indc  \
# 1672498  DALLAS,TX       965257               Y                 R
# 1672501  DALLAS,TX       965257               Y                 R
# 1672533  DALLAS,TX       965257               Y                 R
# 1672535  DALLAS,TX       965257               Y                 R
# 1672537  DALLAS,TX       965257               Y                 R
# 1672549  DALLAS,TX       965257               Y                 R
# 1672550  DALLAS,TX       965257               Y                 R
# 1672577  DALLAS,TX       965257               Y                 R
# 1672580  DALLAS,TX       965257               Y                 R
# 2944814  DALLAS,TX       965257               Y                 R
# 2944819  DALLAS,TX       965257               Y                 R
# 2944820  DALLAS,TX       965257               Y                 R
# 2944821  DALLAS,TX       965257               Y                 R
# 2944822  DALLAS,TX       965257               Y                 R
# 2944823  DALLAS,TX       965257               Y                 R
# 2944824  DALLAS,TX       965257               Y                 R
# 2944825  DALLAS,TX       965257               Y                 R
# 2944826  DALLAS,TX       965257               Y                 R
# 2944827  DALLAS,TX       965257               Y                 R
# 2944828  DALLAS,TX       965257               Y                 R
#
#         supp1_bus_pander   unnamed_0    make      model    sub_model  \
# 1672498                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672501                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672533                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672535                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672537                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672549                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672550                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672577                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 1672580                N  13509552.0  NISSAN   ALTIMA S  S 2.5 Sedan
# 2944814                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944819                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944820                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944821                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944822                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944823                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944824                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944825                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944826                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944827                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
# 2944828                N   8546838.0  NISSAN  ALTIMA SV       SV 2.5
#
#         model_year
# 1672498     2010.0
# 1672501     2010.0
# 1672533     2010.0
# 1672535     2010.0
# 1672537     2010.0
# 1672549     2010.0
# 1672550     2010.0
# 1672577     2010.0
# 1672580     2010.0
# 2944814     2014.0
# 2944819     2014.0
# 2944820     2014.0
# 2944821     2014.0
# 2944822     2014.0
# 2944823     2014.0
# 2944824     2014.0
# 2944825     2014.0
# 2944826     2014.0
# 2944827     2014.0
# 2944828     2014.0
#
# [20 rows x 33 columns]

# %%
# confirm a different way that join is working
# list the unique vehicle ids in null and not null and save as a list
# then find the rows in vehicle_sample that have these ids
null_ids = vehicle_null['vehicle_id'].unique()
null_ids = null_ids.tolist()
not_null_ids = vehicle_not_null['vehicle_id'].unique()
not_null_ids = not_null_ids.tolist()

# %%
# 524 vehicles that we saw previously in vehicle_not_null
vehicle_sample[vehicle_sample['vehicle_id'].isin(not_null_ids)]
# Out:
#        unnamed_0  vehicle_id       make                 model      sub_model  \
# 5       24402807   927448862      MAZDA             5 TOURING        Touring
# 121      3300816   963762976     SUBARU  OUTBACK 2.5I LIMITED   2.5i Limited
# 1101     8546838   981248430     NISSAN             ALTIMA SV         SV 2.5
# 1302     6597458   941459514      DODGE        CHALLENGER SXT            SXT
# 1777    25751721   954625900       FORD          FUSION SPORT          Sport
# ...          ...         ...        ...                   ...            ...
# 99174   17273505   902735775       FORD          MUSTANG BASE         Deluxe
# 99438   14988620   961431641  CHEVROLET             MALIBU LT             LT
# 99453    8752252   931945430       FORD    EXPEDITION LIMITED        Limited
# 99819   24444706   919807536   CADILLAC     ESCALADE ESV BASE           Base
# 99880   19859054   965138608   CADILLAC              CTS BASE  Sedan & Wagon
#
#        model_year
# 5            2006
# 121          2016
# 1101         2014
# 1302         2013
# 1777         2012
# ...           ...
# 99174        2008
# 99438        2009
# 99453        2005
# 99819        2008
# 99880        2011
#
# [524 rows x 6 columns]

# %%
# no vehicle ids are in vehicle sample that are in the mega table as null
vehicle_sample[vehicle_sample['vehicle_id'].isin(null_ids)]
# Out:
# Empty DataFrame
# Columns: [unnamed_0, vehicle_id, make, model, sub_model, model_year]
# Index: []

# %% [markdown]
# Completed analysis on null values. Further analysis is on the not null vehicle table.

# %%
# want to explore average model years of car makes
# create a array that has all of the unique makes that have values in the mega_table
vehicle_makes = vehicle_not_null['make'].unique()
vehicle_makes
# Out:
# array(['TOYOTA', 'LAND ROVER', 'HONDA', 'NISSAN', 'LEXUS', 'CHRYSLER',
#        'FORD', 'ISUZU', 'CHEVROLET', 'BUICK', 'JEEP', 'KIA', 'LINCOLN',
#        'GMC', 'SUBARU', 'MITSUBISHI', 'DODGE', 'ACURA', 'CADILLAC',
#        'INFINITI', 'OLDSMOBILE', 'HYUNDAI', 'MAZDA', 'VOLVO', 'BMW',
#        'MERCEDES-BENZ', 'MERCURY', 'PONTIAC', 'AUDI', 'VOLKSWAGEN',
#        'SATURN', 'Dodge', 'Oldsmobile', 'RAM', 'SCION', 'SUZUKI'],
#       dtype=object)

# %%
# create an empty dataframe
# fill the dataframe with the average year for each make
make_average_year = pd.DataFrame(columns = ['make', 'avg_model_year'])
for i in range(len(vehicle_makes)-1):
    make_average_year = make_average_year.append({'make': vehicle_makes[i], 'avg_model_year':(vehicle_not_null.loc[vehicle_not_null['make'] == vehicle_makes[i]])['model_year'].mean()}, ignore_index = True)

# %%
# can look at the oldest car makes that might need more tire changes, per Patrick
make_average_year.sort_values(by = 'avg_model_year')
# Out:
#              make  avg_model_year
# 32     Oldsmobile     1967.000000
# 20     OLDSMOBILE     1988.913043
# 31          Dodge     2000.000000
# 26        MERCURY     2000.011111
# 7           ISUZU     2001.000000
# 29     VOLKSWAGEN     2003.310811
# 4           LEXUS     2004.959427
# 1      LAND ROVER     2005.053659
# 9           BUICK     2005.687805
# 17          ACURA     2005.823834
# 10           JEEP     2005.977110
# 28           AUDI     2006.333333
# 23          VOLVO     2006.351064
# 2           HONDA     2006.645016
# 30         SATURN     2006.693548
# 3          NISSAN     2006.756786
# 27        PONTIAC     2006.866412
# 12        LINCOLN     2007.370370
# 8       CHEVROLET     2007.420792
# 16          DODGE     2007.513548
# 14         SUBARU     2007.751938
# 25  MERCEDES-BENZ     2007.964912
# 0          TOYOTA     2008.273039
# 6            FORD     2008.427145
# 15     MITSUBISHI     2008.502110
# 13            GMC     2008.659740
# 5        CHRYSLER     2008.923174
# 19       INFINITI     2009.220994
# 24            BMW     2009.368852
# 22          MAZDA     2009.637444
# 34          SCION     2009.833333
# 11            KIA     2010.823224
# 18       CADILLAC     2010.918919
# 21        HYUNDAI     2011.143119
# 33            RAM     2014.714286

# %%
# do the same for average sales to see which makes are costing the most money
# create an empty dataframe
# fill the dataframe with the average sales for each make
make_average_sales = pd.DataFrame(columns = ['make', 'avg_sales'])
for i in range(len(vehicle_makes)-1):
    make_average_sales = make_average_sales.append({'make': vehicle_makes[i], 'avg_sales':(vehicle_not_null.loc[vehicle_not_null['make'] == vehicle_makes[i]])['sales'].mean()}, ignore_index = True)

# %%
# no clear pattern for older cars costing more
make_average_sales.sort_values(by = 'avg_sales')
# Out:
#              make   avg_sales
# 32     Oldsmobile   11.068571
# 18       CADILLAC   12.208559
# 22          MAZDA   12.948514
# 25  MERCEDES-BENZ   12.971053
# 27        PONTIAC   13.082328
# 11            KIA   13.332634
# 3          NISSAN   13.446645
# 20     OLDSMOBILE   14.126087
# 16          DODGE   14.262581
# 2           HONDA   14.900637
# 0          TOYOTA   15.797207
# 26        MERCURY   16.318222
# 4           LEXUS   16.407542
# 9           BUICK   16.614683
# 14         SUBARU   17.497700
# 21        HYUNDAI   18.301193
# 19       INFINITI   18.762680
# 15     MITSUBISHI   18.813460
# 5        CHRYSLER   19.964433
# 8       CHEVROLET   20.187952
# 17          ACURA   21.190207
# 29     VOLKSWAGEN   21.334932
# 30         SATURN   22.118548
# 6            FORD   22.292256
# 7           ISUZU   22.881111
# 1      LAND ROVER   23.633463
# 10           JEEP   23.644421
# 24            BMW   26.120820
# 13            GMC   29.895039
# 23          VOLVO   33.660426
# 12        LINCOLN   36.276667
# 34          SCION   37.443333
# 31          Dodge   38.985000
# 33            RAM   69.229048
# 28           AUDI  131.578667

# %%
# code that will be useful when we are using accre to see which people have more than 1 car
indiv_by_vehicle = vehicle_not_null.groupby(['indiv_id'])['vehicle_id'].nunique().reset_index()
print(indiv_by_vehicle.loc[indiv_by_vehicle['vehicle_id'] > 1])

# %%
# some eda on model year location
vehicles_not_null_tires_only = vehicle_not_null[(vehicle_not_null['prod_group_code'] == 5.0)]
vehicles_not_null_tires_only = vehicles_not_null_tires_only.drop_duplicates(subset=['vehicle_id'])
model_year_counts = pd.DataFrame(vehicles_not_null_tires_only['model_year'].value_counts())
model_year_counts = model_year_counts.reset_index()
model_year_counts.columns = ['years', 'counts']
model_year_counts = model_year_counts[:20]
x_values = model_year_counts.iloc[:,0]
y_values = model_year_counts.iloc[:,1]

# %%
# plotting counts by model year
plt.bar(x_values, height = y_values, width = 0.9)
plt.xticks(rotation = 90)
plt.xticks(np.arange(min(x_values), max(x_values)+1, 1.0))
plt.show()

# %%
# some eda on make of cars
make_counts = pd.DataFrame(vehicles_not_null_tires_only['make'].value_counts())
make_counts = make_counts.reset_index()
make_counts.columns = ['makes', 'counts']
make_counts = make_counts[:20]
x_values = make_counts.iloc[:,0]
y_values = make_counts.iloc[:,1]

# %%
# plotting counts by make of vehicles
plt.bar(x_values, height = y_values, width = 0.9)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Some EDA on other variables outside of vehicles

# %%
# some eda on msa location
mega_table_tires_only = mega_table[(mega_table['prod_group_code'] == 5.0)]
msa_counts = pd.DataFrame(mega_table_tires_only['msa_'].value_counts())
msa_counts = msa_counts.reset_index()
msa_counts.columns = ['locations', 'counts']
msa_counts = msa_counts[:20]
x_values = msa_counts.iloc[:,0]
y_values = msa_counts.iloc[:,1]

# %%
# plotting counts by location
# need to eliminate the comma variable
plt.bar(x_values, height = y_values, width = 0.9)
plt.xticks(rotation = 90)
plt.show()

# %%
# found that alot (666K) of the msa location identifiers are ' which seems to be a placeholder like the 1 for vehicle_id
mega_table.loc[mega_table['msa_'] == ',']
# Out:
#          unnamed_0_x  store_id    tran_id        date  article_id  \
# 176              177    120383  991719700  2018-07-03     7046930
# 177              178    120383  991719700  2018-07-03     7008190
# 178              179    120383  991719700  2018-07-03     7087076
# 179              180    120383  991719700  2018-07-03     7013066
# 180              181    120383  991719700  2018-07-03     7001708
# ...              ...       ...        ...         ...         ...
# 4000317      4000318    121800  991155950  2017-11-22     7007582
# 4000318      4000319    121800  991155950  2017-11-22     7040215
# 4000319      4000320    121800  991155950  2017-11-22     7089565
# 4000320      4000321    121800  991155950  2017-11-22     7089566
# 4000321      4000322    121800  991155950  2017-11-22        3535
#
#             indiv_id  vehicle_id  units   sales  prod_group_code  ... msa_  \
# 176      320867082.0   946058946    0.0    0.00              4.0  ...    ,
# 177      320867082.0   946058946    0.0    6.00              4.0  ...    ,
# 178      320867082.0   946058946    0.0  280.00              4.0  ...    ,
# 179      320867082.0   946058946    0.0  -13.92              5.0  ...    ,
# 180      320867082.0   946058946    0.0  -60.00              4.0  ...    ,
# ...              ...         ...    ...     ...              ...  ...  ...
# 4000317  546072990.0   964832272    2.0   14.00              4.0  ...    ,
# 4000318  546072990.0   964832272    0.0   24.94              5.0  ...    ,
# 4000319  546072990.0   964832272    0.0    0.00              5.0  ...    ,
# 4000320  546072990.0   964832272    0.0  -46.00              5.0  ...    ,
# 4000321  546072990.0   964832272    2.0  171.98              5.0  ...    ,
#
#          unnamed_0_y email_optin_ind  ah1_res_bus_indc supp1_bus_pander  \
# 176         11531493               Y                 R                N
# 177         11531493               Y                 R                N
# 178         11531493               Y                 R                N
# 179         11531493               Y                 R                N
# 180         11531493               Y                 R                N
# ...              ...             ...               ...              ...
# 4000317     16050829               Y                 R                N
# 4000318     16050829               Y                 R                N
# 4000319     16050829               Y                 R                N
# 4000320     16050829               Y                 R                N
# 4000321     16050829               Y                 R                N
#
#          unnamed_0 make model sub_model model_year
# 176            NaN  NaN   NaN       NaN        NaN
# 177            NaN  NaN   NaN       NaN        NaN
# 178            NaN  NaN   NaN       NaN        NaN
# 179            NaN  NaN   NaN       NaN        NaN
# 180            NaN  NaN   NaN       NaN        NaN
# ...            ...  ...   ...       ...        ...
# 4000317        NaN  NaN   NaN       NaN        NaN
# 4000318        NaN  NaN   NaN       NaN        NaN
# 4000319        NaN  NaN   NaN       NaN        NaN
# 4000320        NaN  NaN   NaN       NaN        NaN
# 4000321        NaN  NaN   NaN       NaN        NaN
#
# [665776 rows x 33 columns]
